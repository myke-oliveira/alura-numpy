# %% [markdown]
# <a href="https://colab.research.google.com/github/myke-oliveira/alura-numpy/blob/main/Alura_Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cd drive/MyDrive/Alura/
# !ls
# Out:
# apples_ts.csv  bytebank.csv  citrus.csv  drive	README.md  sample_data

# %%
BASEDIR = "drive/MyDrive/Alura"

with open(f"{BASEDIR}/README.md", "r") as file:
    print(file.read())
# Out:
# # numpy
# Curso de Numpy na Alura
